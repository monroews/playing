# %%
# !pip install onshape_client
# Out:
# Collecting onshape_client
#   Downloading https://files.pythonhosted.org/packages/18/07/fdd4df5b81c17e9b31e41c61e21cd4a68e454879550058d04b4f5cf202a5/onshape_client-0.0.25.tar.gz (450kB)
#      |████████████████████████████████| 460kB 5.1MB/s
# Requirement already satisfied: urllib3>=1.15 in /usr/local/lib/python3.6/dist-packages (from onshape_client) (1.24.3)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from onshape_client) (1.12.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from onshape_client) (2019.6.16)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from onshape_client) (2.5.3)
# Requirement already satisfied: requests_oauthlib in /usr/local/lib/python3.6/dist-packages (from onshape_client) (1.2.0)
# Collecting ruamel.yaml (from onshape_client)
#   Downloading https://files.pythonhosted.org/packages/8b/3e/afb241fadff274c7bebe5b8295dade710208a97fdca48706290b3f4f77d3/ruamel.yaml-0.16.1-py2.py3-none-any.whl (122kB)
#      |████████████████████████████████| 122kB 45.2MB/s
# Requirement already satisfied: pathlib in /usr/local/lib/python3.6/dist-packages (from onshape_client) (1.0.1)
# Collecting enum34 (from onshape_client)
#   Downloading https://files.pythonhosted.org/packages/af/42/cb9355df32c69b553e72a2e28daee25d1611d2c0d9c272aa1d34204205b2/enum34-1.1.6-py3-none-any.whl
# Collecting pint (from onshape_client)
#   Downloading https://files.pythonhosted.org/packages/15/9d/bf177ebbc57d25e9e296addc14a1303d1e34d7964af5df428a8332349c42/Pint-0.9-py2.py3-none-any.whl (138kB)
#      |████████████████████████████████| 143kB 47.4MB/s
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from requests_oauthlib->onshape_client) (2.21.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests_oauthlib->onshape_client) (3.1.0)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.8" (from ruamel.yaml->onshape_client)
#   Downloading https://files.pythonhosted.org/packages/96/62/ed93cb8ae7e2ad8c5fe874e8027306aeee0c6a02c04fa015b5f99d14b3db/ruamel.yaml.clib-0.1.2-cp36-cp36m-manylinux1_x86_64.whl (549kB)
#      |████████████████████████████████| 552kB 33.5MB/s
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests_oauthlib->onshape_client) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests_oauthlib->onshape_client) (3.0.4)
# Building wheels for collected packages: onshape-client
#   Building wheel for onshape-client (setup.py) ... done
#   Created wheel for onshape-client: filename=onshape_client-0.0.25-cp36-none-any.whl size=948529 sha256=20f3b4677575c3c970401d788a197a261ab75bc40cde90906d12a22a4f72fbd3
#   Stored in directory: /root/.cache/pip/wheels/ba/de/2e/ea93ea43dec98336676729ff93b653682dc92f462516041994
# Successfully built onshape-client
# Installing collected packages: ruamel.yaml.clib, ruamel.yaml, enum34, pint, onshape-client
# Successfully installed enum34-1.1.6 onshape-client-0.0.25 pint-0.9 ruamel.yaml-0.16.1 ruamel.yaml.clib-0.1.2

# %%
"""For getting measurements defined by the custom "measure" feature: https://cad.onshape.com/documents/78aa66ffe6f1daceb9cfad3d/v/746f3ce1b31d39942593ed54/e/92549789b92e9aa35f676f4e

To fetch measurements from the API:

1. Make sure the desired geometry is defined using the feature within this document. The "use measurements variable" checkbox should be selected.
2. Call the Evaluate Featurescript API call with your client/code with the following script:

	function(context, queries) {
            return getVariable(context, "m");
        }

This will return all the variables defined under "m", ie, m.radius, m.my_custom_length, etc...
3. Now use the resulting map from measurements feature name to value within your code.
"""

from onshape_client.client import Client
from onshape_client.onshape_url import OnshapeElement
from onshape_client.models.bt_feature_script_eval_call import BTFeatureScriptEvalCall
from onshape_client.utility import parse_quantity
import json

script = \
    r"""
    function(context, queries) {
            return getVariable(context, "m");
        }
    """

element = OnshapeElement(
    "https://cad.onshape.com/documents/72ffa085b9b0c6d953360068/w/788dd87fafea10c4ef32fd5c/e/25c562a9ee5c8316b7745fc5")
script_call = BTFeatureScriptEvalCall(script=script)
client = Client(configuration={"base_url": "https://cad.onshape.com",
"secret_key": "b1yUWVORDqPI3ERMI23oU2WxcG14vp2iJ0JzODIRvw2PACCL",
"access_key": "0hcHACpwVrtO2mGLRMVebIJG"})

response = client.part_studios_api.eval_feature_script(element.did,
                                                       element.wvm,
                                                       element.wvmid,
                                                       element.eid,
                                                       bt_feature_script_eval_call=script_call, _preload_content=False)
measurements = json.loads(response.data.decode("utf-8"))["result"]["message"]["value"]
parsed_measurements = {}
for m in measurements:
    key = m["message"]["key"]["message"]["value"]
    value = parse_quantity(m["message"]["value"]["message"])
    parsed_measurements[key] = value
print("Measurements: \n" + str(parsed_measurements))
"""
Measurements: 
{'distance_from_polygon_to_square': '0.1308455707096832*meter', 'diameter': '0.0868175271040671*meter', 'polygon_side_length': '0.05706864859958895*meter'}
"""
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-ef0adbc3e290> in <module>()
#      27
#      28 element = OnshapeElement(
# ---> 29     "https://cad.onshape.com/documents/72ffa085b9b0c6d953360068/w/788dd87fafea10c4ef32fd5c/e/25c562a9ee5c8316b7745fc5")
#      30 script_call = BTFeatureScriptEvalCall(script=script)
#      31 client = Client(configuration={"base_url": "https://cad.onshape.com",
#
# /usr/local/lib/python3.6/dist-packages/onshape_client/onshape_url.py in __init__(self, url, *args, **kwargs)
#      21     def __init__(self, url, *args, **kwargs):
#      22
# ---> 23         self.client = Client.get_client()
#      24
#      25         self.original_url = url
#
# /usr/local/lib/python3.6/dist-packages/onshape_client/client.py in get_client(create_if_needed)
#      45         if not client:
#      46             if create_if_needed:
# ---> 47                 client = Client()
#      48             else:
#      49                 raise Exception("Please manually instantiate the client.")
#
# /usr/local/lib/python3.6/dist-packages/onshape_client/client.py in __init__(self, keys_file, configuration, stack_key, open_authorize_grant_callback)
#      78             final_configuration = configuration
#      79         elif keys_file:
# ---> 80             final_configuration = self.get_configuration_from_keys_file(keys_file, stack_key)
#      81         else:
#      82             raise EnvironmentError("API keys were not properly set.")
#
# /usr/local/lib/python3.6/dist-packages/onshape_client/client.py in get_configuration_from_keys_file(keys_file, stack_key)
#      54         try:
#      55             yaml = YAML()
# ---> 56             configurations_file = yaml.load(Path(keys_file))
#      57             final_configuration = configurations_file[stack_key if stack_key else configurations_file['default_stack']]
#      58         except KeyError as e:
#
# /usr/local/lib/python3.6/dist-packages/ruamel/yaml/main.py in load(self, stream)
#     325         if not hasattr(stream, 'read') and hasattr(stream, 'open'):
#     326             # pathlib.Path() instance
# --> 327             with stream.open('rb') as fp:  # type: ignore
#     328                 return self.load(fp)
#     329         constructor, parser = self.get_constructor_parser(stream)
#
# /usr/lib/python3.6/pathlib.py in open(self, mode, buffering, encoding, errors, newline)
#    1181             self._raise_closed()
#    1182         return io.open(str(self), mode, buffering, encoding, errors, newline,
# -> 1183                        opener=self._opener)
#    1184
#    1185     def read_bytes(self):
#
# /usr/lib/python3.6/pathlib.py in _opener(self, name, flags, mode)
#    1035     def _opener(self, name, flags, mode=0o666):
#    1036         # A stub for the opener argument to built-in open()
# -> 1037         return self._accessor.open(self, flags, mode)
#    1038
#    1039     def _raw_open(self, flags, mode=0o777):
#
# /usr/lib/python3.6/pathlib.py in wrapped(pathobj, *args)
#     385         @functools.wraps(strfunc)
#     386         def wrapped(pathobj, *args):
# --> 387             return strfunc(str(pathobj), *args)
#     388         return staticmethod(wrapped)
#     389
#
# FileNotFoundError: [Errno 2] No such file or directory: '/root/.onshape_client_config.yaml'

# %% [markdown]
# Get a key here https://dev-portal.onshape.com/keys
# authorized read access to my documents

# %%
client.base_url = 0hcHACpwVrtO2mGLRMVebIJG 
client.base_key = b1yUWVORDqPI3ERMI23oU2WxcG14vp2iJ0JzODIRvw2PACCL
client(configuration={"base_url": "https://cad.onshape.com",
"secret_key": "PPI...",
"access_key": "q4j..."})
# Out:
#   File "<ipython-input-3-aefcb56c0494>", line 1
#     client.base_url = 0hcHACpwVrtO2mGLRMVebIJG
#                                              ^
# SyntaxError: invalid syntax
