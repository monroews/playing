# %% [markdown]
# William's current model
# k_0 = 0.2875
#
# C = 0.2076
#
# $$k = k_0 e ^ {C \left(1 - \frac{V_{c}}{V_{c_0}}\right) }$$
#
# Terminal velocity equation
# $$V_t = \frac{g d_0^2}{18 \nu_{H_2O}}
# \frac{ \left( \rho_{Floc_0} - \rho_{H_2O} \right)}{\rho_{H_2O}}
# \left( \frac{d}{d_0} \right)^{D_{Fractal} - 1}$$
#
# Replace the terminal velocity ratio with the particle diameters
#
# $$ \frac{V_{c}}{V_{c_0}} = \left(\frac{\frac{d}{d_0}}{\frac{d_0}{d_0}}\right)^{D_{Fractal} - 1} $$
#
# $$ \frac{V_{c}}{V_{c_0}}  = \left(\frac{d}{d_0}\right)^{D_{Fractal} - 1} $$
#
# Substitute this into the equation for k
#
# $$ k = k_0 e ^ {C \left(1 - \left(\frac{d}{d_0}\right)^{D_{Fractal} - 1}\right) } $$
#
# One option would be simplify the previous equation by getting rid of the exponent on d an then see if this fits the data.
#
# $$ k = k_0 e ^ {C \left(1 - \frac{d}{d_0}\right) } $$
#
# or better yet let the exponent be the unknown.
#
# $$ k = k_0 e ^ {\left(\frac{d_0^C - d^C}{d_0^C}\right) } $$
#
# Finally, It would be great to see what form of the equation results from integrating the particle size distribution.
